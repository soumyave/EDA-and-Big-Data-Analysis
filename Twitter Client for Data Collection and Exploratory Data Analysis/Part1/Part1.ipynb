# %% [markdown]
#         NAME          : SOUMYA VENKATESAN                    PERSON NO : 50246599
#
#         TEAMMATE NAME : SHRI SAI SADHANA NATARAJAN           PERSON NO : 50247664

# %%
#PROBLEM 1
sales1<-c(12,14,16,29,30,45,19,20,16, 19, 34, 20)
sales2<-rpois(12,34) 
par(bg="cornsilk")
plot(sales1, col="blue", type="o", ylim=c(0,100), xlab="Month", ylab="Sales" )
title(main="Sales by Month")
lines(sales2, type="o", pch=22, lty=2, col="red")
grid(nx=NA, ny=NULL)
legend("topright", inset=.05, c("Sales1","Sales2"), fill=c("blue","red"), horiz=TRUE)
# Out:
# Plot with title "Sales by Month"

# %%
#PROBLEM 2
sales<-read.table(file.choose(), header=T)
sales 
barplot(as.matrix(sales), main="Sales Data", ylab= "Total",beside=T, col=rainbow(5))
# Out:
#    Sales1 Sales2
# 1  34     45
# 2  23     23
# 3  12     56
# 4  29     34
# 5  34     45
# 6  34     56
# 7  12     89
# 8  80     36
# 9  80     44
# 10 56     66
# 11 55     60
# 12 45     23
# Plot with title "Sales Data"

# %%
#PROBLEM 3
fn<-boxplot(sales,col=c("orange","green"))$stats
text(1.45, fn[3,2], paste("Median =", fn[3,2]), adj=0, cex=.7)
text(0.45, fn[3,1],paste("Median =", fn[3,1]), adj=0, cex=.7)
grid(nx=NA, ny=NULL)
# Out:
# plot without title

# %%
#PROBLEM 4
fb1<-read.csv(file.choose())
aapl1<-read.csv(file.choose())
par(bg="cornsilk")
plot(aapl1$Adj.Close, col="blue", type="o", ylim=c(150,200), xlab="Days", ylab="Price" )
lines(fb1$Adj.Close, type="o", pch=22, lty=2, col="red")
legend("topright", inset=.05, c("Apple","Facebook"), fill=c("blue","red"), horiz=TRUE)
hist(aapl1$Adj.Close, col=rainbow(8))
# Out:
# plot without title
# Plot with title "Histogram of aapl1$Adj.Close"

# %%
#PROBLEM 5
data()
attach(mtcars)
head(mtcars)
summary(mtcars)
detach(mtcars)

library (help=datasets)
library(datasets)
head(uspop)
plot(uspop)
# Out:
# The following objects are masked from mtcars (pos = 3):
#
#     am, carb, cyl, disp, drat, gear, hp, mpg, qsec, vs, wt
#
# The following objects are masked from mtcars (pos = 4):
#
#     am, carb, cyl, disp, drat, gear, hp, mpg, qsec, vs, wt
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.460 20.22 1  0  3    1
#       mpg             cyl             disp             hp
#  Min.   :10.40   Min.   :4.000   Min.   : 71.1   Min.   : 52.0
#  1st Qu.:15.43   1st Qu.:4.000   1st Qu.:120.8   1st Qu.: 96.5
#  Median :19.20   Median :6.000   Median :196.3   Median :123.0
#  Mean   :20.09   Mean   :6.188   Mean   :230.7   Mean   :146.7
#  3rd Qu.:22.80   3rd Qu.:8.000   3rd Qu.:326.0   3rd Qu.:180.0
#  Max.   :33.90   Max.   :8.000   Max.   :472.0   Max.   :335.0
#       drat             wt             qsec             vs
#  Min.   :2.760   Min.   :1.513   Min.   :14.50   Min.   :0.0000
#  1st Qu.:3.080   1st Qu.:2.581   1st Qu.:16.89   1st Qu.:0.0000
#  Median :3.695   Median :3.325   Median :17.71   Median :0.0000
#  Mean   :3.597   Mean   :3.217   Mean   :17.85   Mean   :0.4375
#  3rd Qu.:3.920   3rd Qu.:3.610   3rd Qu.:18.90   3rd Qu.:1.0000
#  Max.   :4.930   Max.   :5.424   Max.   :22.90   Max.   :1.0000
#        am              gear            carb
#  Min.   :0.0000   Min.   :3.000   Min.   :1.000
#  1st Qu.:0.0000   1st Qu.:3.000   1st Qu.:2.000
#  Median :0.0000   Median :4.000   Median :2.000
#  Mean   :0.4062   Mean   :3.688   Mean   :2.812
#  3rd Qu.:1.0000   3rd Qu.:4.000   3rd Qu.:4.000
#  Max.   :1.0000   Max.   :5.000   Max.   :8.000
# [1]  3.93  5.31  7.24  9.64 12.90 17.10
# plot without title

# %%
#PROBLEM 6
install.packages("ggmap",repos = "https://cran.r-project.org/")
install.packages("ggplot2",repos = "https://cran.r-project.org/")
install.packages("maptools",repos = "https://cran.r-project.org/")
install.packages("lattice", repos = "https://cran.r-project.org/")
install.packages("rgeos", repos = "https://cran.r-project.org/")
# Out:
# Installing package into 'C:/Users/Soumya V/Documents/R/win-library/3.4'
# (as 'lib' is unspecified)
# Warning message:
# "package 'ggmap' is in use and will not be installed"Installing package into 'C:/Users/Soumya V/Documents/R/win-library/3.4'
# (as 'lib' is unspecified)
# Warning message:
# "package 'ggplot2' is in use and will not be installed"Installing package into 'C:/Users/Soumya V/Documents/R/win-library/3.4'
# (as 'lib' is unspecified)
# Warning message:
# "package 'maptools' is in use and will not be installed"Installing package into 'C:/Users/Soumya V/Documents/R/win-library/3.4'
# (as 'lib' is unspecified)
# package 'lattice' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Soumya V\AppData\Local\Temp\RtmpeAHTld\downloaded_packages
# Installing package into 'C:/Users/Soumya V/Documents/R/win-library/3.4'
# (as 'lib' is unspecified)
# package 'rgeos' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Soumya V\AppData\Local\Temp\RtmpeAHTld\downloaded_packages

# %%
library("ggmap")
library("ggplot2")
library("maptools")
library(maps)
visited <- c("SFO", "Madras", "London", "Melbourne","Lima,Peru", "Johannesbury,SA")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("world", fill=TRUE, col="white", bg="lightblue", ylim=c(-60, 90), mar=c(0,0,0,0))
points(visit.x,visit.y, col="red", pch=36)
# Out:
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=SFO&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Madras&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=London&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Melbourne&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Lima,Peru&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Johannesbury,SA&sensor=false
# plot without title

# %%
library("ggmap")
library("maptools")
library(maps)
visited <- c("SFO", "New York City", "Buffalo", "Dallas")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("state", fill=TRUE, col=rainbow(50), bg="lightblue", mar=c(0,0,0,0))
points(visit.x,visit.y, col="yellow", pch=36)
# Out:
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=SFO&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20York%20City&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Buffalo&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Dallas&sensor=false
# plot without title

# %%
#PROBLEM 7
library("lattice")
library("ggplot2")
splom(mtcars[c(1,3,4,5,6)], main="MTCARS Data")
splom(mtcars[c(1,3,4,6)], main="MTCARS Data")
splom(mtcars[c(1,3,4,6)], col=rainbow(5),main="MTCARS Data")
# Out:
# plot without title
# plot without title
# plot without title

# %%
require("lattice")
library("ggplot2")
splom(rock[c(1,2,3,4)],col=rainbow(7) ,main="ROCK Data")
# Out:
# plot without title

# %%
#PROBLEM 8
plotdata <- read.csv(file.choose())
head(plotdata)
tail(plotdata)
library(ggplot2)
ggplot(data = plotdata, aes(x = Type.of.Behavior, y = Sample.Size, fill = Stage.of.Change)) + geom_bar(stat = "identity")
ggplot(data = plotdata, aes(x = Type.of.Behavior, y = Sample.Size, fill = Stage.of.Change)) + geom_bar(stat = "identity") + coord_flip()
plotdata$Stage.of.Change <- factor(plotdata$Stage.of.Change, levels = c("Precontemplation","Contemplation", "Preparation", "Action", "Maintenance"))
ggplot(data = plotdata, aes(x = Type.of.Behavior, y = Sample.Size, fill = factor(Stage.of.Change))) + geom_bar(stat = "identity") + coord_flip()
ggplot(data = plotdata, aes(x = Type.of.Behavior, y = Sample.Size, fill = factor(Stage.of.Change))) + geom_bar(stat = "identity") + coord_flip() + scale_fill_brewer(palette = 12)
ggplot(data = plotdata, aes(x = Type.of.Behavior, y = Sample.Size, fill = factor(Stage.of.Change))) + geom_bar(stat = "identity") + coord_flip() + scale_fill_brewer(palette = 12) + labs(title = "Figure 1  Total Sample Size and Subsamples for Each Stage for Each of the 12 Problem Behaviors", y = "Sample Size", x = "Type of Behavior", fill = "Stage of Change")
# Out:
#   Type.of.Behavior   Sample.Size Stage.of.Change
# 1 Smoking cessation  108         Precontemplation
# 2 Smoking cessation  187         Contemplation
# 3 Smoking cessation    0         Preparation
# 4 Smoking cessation  134         Action
# 5 Smoking cessation  247         Maintenance
# 6 Quitting cocaine     8         Precontemplation
#    Type.of.Behavior      Sample.Size Stage.of.Change
# 55 Mammography screening 60          Maintenance
# 56 Physicians' practices 43          Precontemplation
# 57 Physicians' practices 20          Contemplation
# 58 Physicians' practices  3          Preparation
# 59 Physicians' practices  2          Action
# 60 Physicians' practices 67          Maintenance
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
